# %%
# !pip install python-doctr
# !pip install "python-doctr[torch]"
# !pip install pypdfium2
# Out:
# Requirement already satisfied: python-doctr in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (1.0.1)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (2.10.0)
# Requirement already satisfied: torchvision>=0.15.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (0.25.0)
# Requirement already satisfied: onnx<3.0.0,>=1.12.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (1.21.0)
# Requirement already satisfied: numpy<3.0.0,>=1.16.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (2.2.4)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (1.15.2)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (3.14.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (4.11.0.86)
# Requirement already satisfied: pypdfium2<6.0.0,>=4.11.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (5.8.0)
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (1.4.0)
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (2.1.2)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (1.0.9)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (3.14.5)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.20.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (0.36.0)
# Requirement already satisfied: Pillow>=9.2.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (11.1.0)
# Requirement already satisfied: defusedxml>=0.7.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (0.7.1)
# Requirement already satisfied: anyascii>=0.3.2 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (0.3.3)
# Requirement already satisfied: validators>=0.18.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (0.35.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr) (4.67.1)
# Requirement already satisfied: filelock in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (2025.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (6.0.2)
# Requirement already satisfied: requests in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (4.15.0)
# Requirement already satisfied: six in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from langdetect<2.0.0,>=1.0.9->python-doctr) (1.17.0)
# Requirement already satisfied: protobuf>=4.25.1 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from onnx<3.0.0,>=1.12.0->python-doctr) (5.29.4)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from onnx<3.0.0,>=1.12.0->python-doctr) (0.5.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from torch<3.0.0,>=2.0.0->python-doctr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from torch<3.0.0,>=2.0.0->python-doctr) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from torch<3.0.0,>=2.0.0->python-doctr) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from torch<3.0.0,>=2.0.0->python-doctr) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch<3.0.0,>=2.0.0->python-doctr) (1.3.0)
# Requirement already satisfied: colorama in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.30.0->python-doctr) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch<3.0.0,>=2.0.0->python-doctr) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (2025.1.31)
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-doctr[torch] in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (1.0.1)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (2.10.0)
# Requirement already satisfied: torchvision>=0.15.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (0.25.0)
# Requirement already satisfied: onnx<3.0.0,>=1.12.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (1.21.0)
# Requirement already satisfied: numpy<3.0.0,>=1.16.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (2.2.4)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (1.15.2)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (3.14.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (4.11.0.86)
# Requirement already satisfied: pypdfium2<6.0.0,>=4.11.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (5.8.0)
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (1.4.0)
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (2.1.2)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (1.0.9)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (3.14.5)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.20.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (0.36.0)
# Requirement already satisfied: Pillow>=9.2.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (11.1.0)
# Requirement already satisfied: defusedxml>=0.7.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (0.7.1)
# Requirement already satisfied: anyascii>=0.3.2 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (0.3.3)
# Requirement already satisfied: validators>=0.18.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (0.35.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from python-doctr[torch]) (4.67.1)
# Requirement already satisfied: filelock in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr[torch]) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr[torch]) (2025.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr[torch]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr[torch]) (6.0.2)
# Requirement already satisfied: requests in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr[torch]) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr[torch]) (4.15.0)
# Requirement already satisfied: six in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from langdetect<2.0.0,>=1.0.9->python-doctr[torch]) (1.17.0)
# Requirement already satisfied: protobuf>=4.25.1 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from onnx<3.0.0,>=1.12.0->python-doctr[torch]) (5.29.4)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from onnx<3.0.0,>=1.12.0->python-doctr[torch]) (0.5.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch]) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch]) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch<3.0.0,>=2.0.0->python-doctr[torch]) (1.3.0)
# Requirement already satisfied: colorama in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.30.0->python-doctr[torch]) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch<3.0.0,>=2.0.0->python-doctr[torch]) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.20.0->python-doctr[torch]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.20.0->python-doctr[torch]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.20.0->python-doctr[torch]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub<2.0.0,>=0.20.0->python-doctr[torch]) (2025.1.31)
# WARNING: python-doctr 1.0.1 does not provide the extra 'torch'
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pypdfium2 in c:\users\pardh\appdata\local\programs\python\python313\lib\site-packages (5.8.0)
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

pdf_path = r"C:\Users\pardh\Downloads\PDP\24-25 Assignment 1\Please upload your assignment file (in .pdf format) (File responses)\22BCS001 - ABHIGYAN NIRANJAN IIIT Dharwad.pdf"

print("Loading docTR...")
model = ocr_predictor(pretrained=True)

print("Reading PDF...")
doc = DocumentFile.from_pdf(pdf_path)

print("Running OCR...")
result = model(doc)

data = result.export()

full_text = ""

for i, page in enumerate(data["pages"]):
    full_text += f"\n===== PAGE {i+1} =====\n"

    for block in page["blocks"]:
        for line in block["lines"]:
            line_text = " ".join(word["value"] for word in line["words"])
            full_text += line_text + "\n"

print(full_text)

with open("doctr_output.txt", "w", encoding="utf-8") as f:
    f.write(full_text)

print("\nSaved to doctr_output.txt")
# Out:
# Loading docTR...
# Reading PDF...
# Running OCR...
#
# ===== PAGE 1 =====
# CS304 Artificial Intelligence
# Assignment 2
# Name: Abhigyan Niranjan
# Roll no: 22BCS001
# Q1: "As per the law, it is a crime for an American to sell weapons
# to hostile nations. Country A, an enemy of America, has some
# missiles, and all the missiles were sold to it by Robert, who is an
# American citizen."
# Now, prove that "Robert is a criminal."
# Given:
# american(p)
# A
# hostile(q)
# 1 weapon(r)
# A
# sells(p, q, r) - criminal(p)
# enemy (A, America)
# missile(t1) A owns (A, t1)
# - Vp missile(p) A owns (A, p) >> sells(Robert,
# A, p)
# american(Robert)
# Additionally:
# missile(p) - weapon(p)
#
# ===== PAGE 2 =====
# enemy(p, America) - hostile(p)
# Proof using Forward Checking:
# Step 1
# american(Robert)
# missle(t1)
# owns(A, t1)
# enemy(A, America)
# Step 2
# weapon(t1)
# sells(Robert, A, t1)
# hostile(A)
# american(Robert)
# missle(t1)
# owns(A, t1)
# enemy(A, America)
# Step 3
# sells(Robert, A, t1)
# weapon(t1)
# sells(Robert,A, t1)
# hostile(A)
# american(Robert)
# missle(t1)
# owns(A, t1)
# enemy(A, America)
#
# ===== PAGE 3 =====
# Q2: Assume the following facts:
# John likes all kinds of food.
# Apple and vegetable are food.
# Anything anyone eats and is not killed is food.
# Anil eats peanuts and still alive.
# Harry eats everything that Anil eats.
# Prove by resolution that "John likes peanuts."
# Converting facts to first order logic:
# Vx food(x) - likes (John, x)
# food(Apple) A food(Vegetables)
# Vx Vy eats(x, y) A -killed(x, y) >> foodly)
# eats (Anil, Peanuts) A alive(Anil)
# Vx eats(Anil, x) - eats (Harry, x)
# Vx killed(x) - alive(x)
# Vx alive(x) > -killed(x)
# Converting expressions to CNF:
# Vx food(x) V likes( (John, x)
# food(Apple) A food(Vegetables)
# Vx Vy weats(x, y) V killed(x, y)) V
# foodly)
# eats (Anil, Peanuts) A alive(Anil)
# Vx reats (Anil, x) V eats (Harry, x)
# Vx killed(x) V alive(x)
#
# ===== PAGE 4 =====
# Standardize variables and drop quantifiers:
# food(x) V likes(John, x)
# foo(Apple)
# food(Vegetable)
# reatsly, z) V killed(y) V food(z)
# eats (Anil, Peanuts)
# alive(Anil)
# reats( (Anil, w) V eats - (Harry, w)
# killed(g) V alivelg)
# To prove: likes (John, Peanuts)
# Resolution graph:
#
# ===== PAGE 5 =====
# Contradiction
# -alive(Anil)
# alive(Anil)
# (Anil/g}
# killed(Anil)
# alive(g) V -killed(g)
# (Anil/y}
# -eats(y, Peanuts) V killed(y)
# eats(Anil, Peanuts)
# (Peanuts Iz}
# -food(Peanuts)
# -eats(y, z)vi killed(y) vt food(z)
# (Peanuts/x}
# likes(John, Peanuts)
# -food(x) vl likes(John,: x)
# Assumption
# Therefore likes (John, Peanuts)
# Q3: Assume the following facts:
# Amit only likes easy courses.
# Science courses are hard.
# All the courses in the basket weaving department are easy.
# BK-304 is a basket weaving course.
# Use resolution to answer: "What courses would Amit like?"
# Converting facts to first order logic:
# Vx course(x) A easy(x) - likes (Amit, x)
#
# ===== PAGE 6 =====
# Vx scienceCourse(x) - reasy(x)
# Vx basketWeavingCourse(x) > easy(x)
# basketleavingCourse(BK-304)
# Vx scienceCourse(x) > course(x)
# Vx basketWeavingCourse(x) > course(x)
# Converting expressions to CNF:
# Vx rcourse(x) V reasy(x) V likes (Amit, x)
# Vx scienceCourse(x) V reasy(x)
# Vx -basketWeavingCourse(x) V easy(x)
# basketWeavingCourse(BK-304)
# Vx -scienceCourse(x) V course(x)
# Vx -basketWeavingCourse(x) V course(x)
# Standardize variables and drop quantifiers:
# "course(x) V weasy(x) V likes (Amit, x)
# wscienceCoursely) V reasyly)
# -basketWeaavingCourse(z) V easy(z)
# basketWeavingCourse(BK-304)
# *scienceCourse(w) V course(w)
# -basketWeavingCourse(k) V course(k)
# Resolution Graph:
#
# ===== PAGE 7 =====
# likes(Amit, BK-304)
# (BK-304/x}
# easy(BK-304)
# course(BK-304)
# -course(x) V -easy(x) vI likes(Amit, x)
# (BK-304/k}
# basketWeavingCourse(BK-304)
# -basketWeavingCourse(k)1 V course(k)
# (BK-304/z}
# basketWeavingCourse(BK-304)
# -basketWeavingCourse(2) V easy(z)
# Therefore, Amit likes the course BK-304
#
#
# Saved to doctr_output.txt
